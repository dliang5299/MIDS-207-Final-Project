# %% [markdown]
# # Final Project: Data processing

# %% [markdown]
# ## Initial Data Intake

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import libraries
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import matplotlib.pyplot as plt
import seaborn as sns

import os

# Define paths for data
DATA_PATH = "/content/drive/MyDrive/DATASCI 207/Final Project/NBA data - raw"
DATA_PATH_PROC = "/content/drive/MyDrive/DATASCI 207/Final Project/NBA data - processed"

# %%
# Function to loop through directories to read in files
def load_data(path_to_data):
    '''Load datasets
    Parameters:
    path_to_data (str): This is the path to data

    Returns:
    nba_data: A pandas dataframe
    '''
    # List all folders in data directory
    dir_list = os.listdir(path_to_data)
    # Initialize data
    nba_dfs = []
    vegas_dfs = []
    # Loop through NBA files
    for dir in dir_list:
      df = pd.read_csv(os.path.join(path_to_data, dir, "raw_scores.txt"),
                       delimiter=',', skiprows=[0], header=None)
      df['season'] = dir
      nba_dfs.append(df)
    # Loop through Vegas files
    for dir in dir_list:
      df = pd.read_csv(os.path.join(path_to_data, dir, "vegas.txt"),
                       delimiter=',')
      vegas_dfs.append(df)
    # Concatenate all DataFrames into a single DataFrame
    nba_df = pd.concat(nba_dfs, ignore_index=True)
    vegas_df = pd.concat(vegas_dfs, ignore_index=True)
    # Name columns
    nba_df.columns = ["game_date", "game_sequence","game_id","team_id","team_abbr",
                      "team_city","game_result","pts_q1","pts_q2","pts_q3",
                      "pts_q4","pts_ot1","pts_ot2","pts_ot3","pts_ot4","pts_ot5",
                      "pts_ot6","pts_ot7","pts_ot8","pts_ot9","pts_ot10","pts_tot",
                      "fg_pct","ft_pct","fg3_pct","ast","reb","tov","season"]

    return nba_df, vegas_df

# %%
# Load data
nba_df, vegas_df = load_data(DATA_PATH)

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Joining datasets

# %%
# Show NBA columns
nba_df.columns
# Out:
# Index(['game_date', 'game_sequence', 'game_id', 'team_id', 'team_abbr',
#        'team_city', 'game_result', 'pts_q1', 'pts_q2', 'pts_q3', 'pts_q4',
#        'pts_ot1', 'pts_ot2', 'pts_ot3', 'pts_ot4', 'pts_ot5', 'pts_ot6',
#        'pts_ot7', 'pts_ot8', 'pts_ot9', 'pts_ot10', 'pts_tot', 'fg_pct',
#        'ft_pct', 'fg3_pct', 'ast', 'reb', 'tov', 'season'],
#       dtype='object')

# %%
# Show Vegas columns
vegas_df.columns
# Out:
# Index(['Date', 'Location', 'Team', 'OppTeam', 'TeamId', 'GameId',
#        'PercentBet_ML', 'Open_Line_ML', 'Pinnacle_ML', '5dimes_ML',
#        'Heritage_ML', 'Bovada_ML', 'Betonline_ML', 'Average_Line_ML',
#        'Best_Line_ML', 'Worst_Line_ML', 'PercentBet_Spread',
#        'Open_Line_Spread', 'Open_Odds_Spread', 'Pinnacle_Line_Spread',
#        'Pinnacle_Odds_Spread', '5dimes_Line_Spread', '5dimes_Odds_Spread',
#        'Heritage_Line_Spread', 'Heritage_Odds_Spread', 'Bovada_Line_Spread',
#        'Bovada_Odds_Spread', 'Betonline_Line_Spread', 'Betonline_Odds_Spread',
#        'Average_Line_Spread', 'Average_Odds_Spread', 'Best_Line_Spread',
#        'Worst_Line_Spread', 'Best_Odds_Spread', 'Worst_Odds_Spread',
#        'PercentBet_OU', 'Open_Line_OU', 'Open_Odds_OU', 'Pinnacle_Line_OU',
#        'Pinnacle_Odds_OU', '5dimes_Line_OU', '5dimes_Odds_OU',
#        'Heritage_Line_OU', 'Heritage_Odds_OU', 'Bovada_Line_OU',
#        'Bovada_Odds_OU', 'Betonline_Line_OU', 'Betonline_Odds_OU',
#        'Average_Line_OU', 'Average_Odds_OU', 'Best_Line_OU', 'Worst_Line_OU',
#        'Best_Odds_OU', 'Worst_Odds_OU', 'Pts', 'Spread', 'Result', 'Total'],
#       dtype='object')

# %%
# Show that some NBA OT columns have no info
nba_df[['pts_ot5', 'pts_ot6', 'pts_ot7', 'pts_ot8', 'pts_ot9', 'pts_ot10']].describe()

# Drop NBA OT columns
nba_df = nba_df.drop(['pts_ot5', 'pts_ot6', 'pts_ot7', 'pts_ot8', 'pts_ot9', 'pts_ot10'], axis=1)

# %%
# Select desired Vegas columns
vegas_df = vegas_df[['Location', 'TeamId', 'GameId', 'Average_Line_Spread', 'Spread', 'Result', 'Average_Odds_Spread']]
vegas_df.columns = ['location', 'team_id', 'game_id', 'vegas_spread', 'spread', 'result', 'spread_odds']

# Merge data
combined_df = pd.merge(nba_df, vegas_df, on=['team_id', 'game_id'], how='left')

# Set ID types as string vars
combined_df['game_id'] = combined_df['game_id'].astype(str)
combined_df['team_id'] = combined_df['team_id'].astype(str)

# %%
# Print data dimensions
print("Combined shape:", combined_df.shape)
print("NBA data shape:", nba_df.shape)
print("Vegas data shape:", vegas_df.shape)
# Out:
# Combined shape: (17226, 28)
# NBA data shape: (17226, 23)
# Vegas data shape: (17208, 7)

# %% [markdown]
# ### Cleaning anomalies

# %%
# Check NA counts
print(combined_df.isna().sum())
# Out:
# game_date         0
# game_sequence     0
# game_id           0
# team_id           0
# team_abbr         0
# team_city         0
# game_result       0
# pts_q1            0
# pts_q2            0
# pts_q3            0
# pts_q4            0
# pts_ot1           0
# pts_ot2           0
# pts_ot3           0
# pts_ot4           0
# pts_tot           0
# fg_pct            0
# ft_pct            0
# fg3_pct           0
# ast               0
# reb               0
# tov               0
# season            0
# location         18
# vegas_spread     22
# spread           18
# result           18
# spread_odds      22
# dtype: int64

# %%
# Inspect games without Vegas spread
combined_df[combined_df['vegas_spread'].isna()]
# Out:
#         game_date  game_sequence   game_id     team_id team_abbr  \
# 1698   2017-02-19              1  31600001  1610616833       EST
# 1699   2017-02-19              1  31600001  1610616834       WST
# 4888   2013-04-16              2  21201214  1610612754       IND
# 4889   2013-04-16              2  21201214  1610612738       BOS
# 4974   2014-11-01              1  21400027  1610612742       DAL
# 4975   2014-11-01              1  21400027  1610612740       NOP
# 6748   2015-03-06              5  21400920  1610612748       MIA
# 6749   2015-03-06              5  21400920  1610612764       WAS
# 7540   2015-11-06              6  21500080  1610612748       MIA
# 7541   2015-11-06              6  21500080  1610612754       IND
# 8984   2016-02-14              1  31500001  1610616834       WST
# 8985   2016-02-14              1  31500001  1610616833       EST
# 10340  2018-11-20              2  21800249  1610612746       LAC
# 10341  2018-11-20              2  21800249  1610612764       WAS
# 10664  2018-12-12              7  21800411  1610612760       OKC
# 10665  2018-12-12              7  21800411  1610612740       NOP
# 11110  2019-01-12              5  21800634  1610612759       SAS
# 11111  2019-01-12              5  21800634  1610612760       OKC
# 11472  2019-02-07              5  21800815  1610612763       MEM
# 11473  2019-02-07              5  21800815  1610612760       OKC
# 14034  2018-02-18              1  31700001  1610616833       LBN
# 14035  2018-02-18              1  31700001  1610616834       STP
#
#                 team_city game_result  pts_q1  pts_q2  pts_q3  pts_q4  \
# 1698   East NBA All Stars         0-1      53      39      47      43
# 1699   West NBA All Stars         1-0      48      49      47      48
# 4888              Indiana       49-32       0       0       0       0
# 4889               Boston       41-40       0       0       0       0
# 4974               Dallas         2-1      32      34      20      23
# 4975          New Orleans         1-1      26      26      37      15
# 6748                Miami       27-34      18      21      34      24
# 6749           Washington       35-27      40      27      21      11
# 7540                Miami         3-3      26      23      19      19
# 7541              Indiana         3-3      16      33      22      19
# 8984   West NBA All Stars         1-0      40      52      53      51
# 8985   East NBA All Stars         0-1      43      47      46      37
# 10340                  LA        11-6      40      33      22      23
# 10341          Washington        6-11      21      33      32      39
# 10664       Oklahoma City        17-9      28      28      28      30
# 10665         New Orleans       15-15      25      32      32      29
# 11110         San Antonio       25-19      31      29      20      32
# 11111       Oklahoma City       26-16      23      28      35      36
# 11472             Memphis       22-34      32      21      19      23
# 11473       Oklahoma City       35-19      27      24      32      34
# 14034                Team         1-0      31      45      33      39
# 14035                Team         0-1      42      36      34      33
#
#        pts_ot1  pts_ot2  pts_ot3  pts_ot4  pts_tot  fg_pct  ft_pct  fg3_pct  \
# 1698         0        0        0        0      182   0.569   1.000    0.373
# 1699         0        0        0        0      192   0.587   0.750    0.333
# 4888         0        0        0        0        0   0.000   0.000    0.000
# 4889         0        0        0        0        0   0.000   0.000    0.000
# 4974         0        0        0        0      109   0.517   0.579    0.240
# 4975         0        0        0        0      104   0.427   0.750    0.368
# 6748         0        0        0        0       97   0.468   0.684    0.370
# 6749         0        0        0        0       99   0.463   0.889    0.304
# 7540         0        0        0        0       87   0.444   0.692    0.300
# 7541         0        0        0        0       90   0.450   0.542    0.333
# 8984         0        0        0        0      196   0.550   0.500    0.388
# 8985         0        0        0        0      173   0.547   0.600    0.339
# 10340        0        0        0        0      118   0.517   0.833    0.407
# 10341        0        0        0        0      125   0.430   0.821    0.333
# 10664        0        0        0        0      114   0.483   0.630    0.302
# 10665        0        0        0        0      118   0.464   0.800    0.222
# 11110        0        0        0        0      112   0.458   0.700    0.323
# 11111        0        0        0        0      122   0.462   0.862    0.478
# 11472        0        0        0        0       95   0.442   0.870    0.292
# 11473        0        0        0        0      117   0.478   0.636    0.386
# 14034        0        0        0        0      148   0.517   0.833    0.328
# 14035        0        0        0        0      145   0.444   0.818    0.262
#
#        ast  reb  tov   season location  vegas_spread  spread result  \
# 1698    43   50   19  2016-17      NaN           NaN     NaN    NaN
# 1699    60   61   17  2016-17      NaN           NaN     NaN    NaN
# 4888     0    0    0  2012-13      NaN           NaN     NaN    NaN
# 4889     0    0    0  2012-13      NaN           NaN     NaN    NaN
# 4974    25   44   12  2014-15     away           NaN     5.0      W
# 4975    24   47   13  2014-15     home           NaN    -5.0      L
# 6748    18   37   14  2014-15      NaN           NaN     NaN    NaN
# 6749    24   43   15  2014-15      NaN           NaN     NaN    NaN
# 7540    21   40   11  2015-16     away           NaN    -3.0      L
# 7541    21   43   12  2015-16     home           NaN     3.0      W
# 8984    51   59   14  2015-16      NaN           NaN     NaN    NaN
# 8985    34   57   24  2015-16      NaN           NaN     NaN    NaN
# 10340   20   44   17  2018-19      NaN           NaN     NaN    NaN
# 10341   27   44    7  2018-19      NaN           NaN     NaN    NaN
# 10664   23   39   18  2018-19      NaN           NaN     NaN    NaN
# 10665   29   56   17  2018-19      NaN           NaN     NaN    NaN
# 11110   21   52   14  2018-19      NaN           NaN     NaN    NaN
# 11111   27   47    7  2018-19      NaN           NaN     NaN    NaN
# 11472   19   45   24  2018-19      NaN           NaN     NaN    NaN
# 11473   29   44   11  2018-19      NaN           NaN     NaN    NaN
# 14034   40   49   14  2017-18      NaN           NaN     NaN    NaN
# 14035   35   68   17  2017-18      NaN           NaN     NaN    NaN
#
#        spread_odds
# 1698           NaN
# 1699           NaN
# 4888           NaN
# 4889           NaN
# 4974           NaN
# 4975           NaN
# 6748           NaN
# 6749           NaN
# 7540           NaN
# 7541           NaN
# 8984           NaN
# 8985           NaN
# 10340          NaN
# 10341          NaN
# 10664          NaN
# 10665          NaN
# 11110          NaN
# 11111          NaN
# 11472          NaN
# 11473          NaN
# 14034          NaN
# 14035          NaN

# %%
# Games without Vegas spread are limited (6 All-Star games + 16 add'l). Drop games.
combined_df = combined_df.dropna()

# %% [markdown]
# ### Main processing

# %%
# Drop unnecessary columns
combined_df = combined_df.drop(['game_sequence', 'game_result', 'team_city'], axis=1)

# Flip sign of actual spread to correspond with negative spreads indicating a favorite
combined_df['spread'] = combined_df['spread'] * -1

# Sort data
combined_df = combined_df.sort_values(by=['team_id', 'game_date']).reset_index(drop = True)

# Convert game date to datetime variable and calculate days since last game for each team
combined_df['game_date'] = pd.to_datetime(combined_df['game_date'])
combined_df['days_since_last_game'] = combined_df.groupby('team_id')['game_date'].diff().dt.days

# Calculate number of away games in a row for each team
combined_df['consecutive_away_games'] = 0
for i in range(len(combined_df)):
    if combined_df.iloc[i]['location'] == 'away':
        if i == 0 or combined_df.iloc[i-1]['team_id'] != combined_df.iloc[i]['team_id']:
            combined_df.at[i, 'consecutive_away_games'] = 1
        else:
            combined_df.at[i, 'consecutive_away_games'] = combined_df.iloc[i-1]['consecutive_away_games'] + 1
    else:
        combined_df.at[i, 'consecutive_away_games'] = 0

# Remap NOH team to NOP team
combined_df['team_abbr'] = combined_df['team_abbr'].replace('NOH', 'NOP')

# For first game of the season and other outliers, reset days since last game and number of away games
combined_df.loc[combined_df.groupby(['season', 'team_id'])['game_date'].idxmin(), 'days_since_last_game'] = 5
combined_df.loc[combined_df['days_since_last_game'] > 5, 'days_since_last_game'] = 5
combined_df.loc[combined_df.groupby(['season', 'team_id'])['game_date'].idxmin(), 'consecutive_away_games'] = 0

# Encode result column
combined_df['result'] = combined_df['result'].apply(lambda x: 1 if x == 'W' else 0)

# Examine data
combined_df.head()
# Out:
#    game_date   game_id     team_id team_abbr  pts_q1  pts_q2  pts_q3  pts_q4  \
# 0 2012-11-02  21200018  1610612737       ATL      21      23      30      28
# 1 2012-11-04  21200040  1610612737       ATL      30      17      28      29
# 2 2012-11-07  21200055  1610612737       ATL      22      29      14      24
# 3 2012-11-09  21200072  1610612737       ATL      25      21      25      18
# 4 2012-11-11  21200091  1610612737       ATL      19      18      23      16
#
#    pts_ot1  pts_ot2  pts_ot3  pts_ot4  pts_tot  fg_pct  ft_pct  fg3_pct  ast  \
# 0        0        0        0        0      102   0.471   0.882    0.318   23
# 1        0        0        0        0      104   0.494   0.700    0.320   20
# 2        0        0        0        0       89   0.437   0.500    0.318   24
# 3        0        0        0        0       89   0.420   0.750    0.360   20
# 4        0        0        0        0       76   0.417   0.438    0.360   20
#
#    reb  tov   season location  vegas_spread  spread  result  spread_odds  \
# 0   36   13  2012-13     home         -4.92     7.0       0      -108.83
# 1   38   10  2012-13     away          9.17    -9.0       1      -108.00
# 2   51   17  2012-13     home         -3.83    -3.0       1      -109.83
# 3   36   13  2012-13     home          4.67     6.0       0      -109.67
# 4   41   22  2012-13     away          6.42    13.0       0      -109.17
#
#    days_since_last_game  consecutive_away_games
# 0                   5.0                       0
# 1                   2.0                       1
# 2                   3.0                       0
# 3                   2.0                       0
# 4                   2.0                       1

# %%
# Check variable types
print(combined_df.dtypes)
# Out:
# game_date                 datetime64[ns]
# game_id                           object
# team_id                           object
# team_abbr                         object
# pts_q1                             int64
# pts_q2                             int64
# pts_q3                             int64
# pts_q4                             int64
# pts_ot1                            int64
# pts_ot2                            int64
# pts_ot3                            int64
# pts_ot4                            int64
# pts_tot                            int64
# fg_pct                           float64
# ft_pct                           float64
# fg3_pct                          float64
# ast                                int64
# reb                                int64
# tov                                int64
# season                            object
# location                          object
# vegas_spread                     float64
# spread                           float64
# result                             int64
# spread_odds                      float64
# days_since_last_game             float64
# consecutive_away_games             int64
# dtype: object

# %% [markdown]
# ## Generate performance variables for last n games

# %%
# Function for mean of statistics in last n games
def mean_last_n(series, n):
  '''Calculate mean of a variable for last n games
    Parameters:
    series (pd.Series, numeric): This is the variable to calculate the mean for
    n (int): This is the number of games to calculate the mean for

    Returns:
    result: A float, mean of the variable for the last n games
  '''
  series_shift = series.shift(1)
  result = series_shift.rolling(window=n, min_periods=0).mean()

  return result

# Function for winrate in last n games
def wr_last_n(series, n):
  '''Calculate winrate for last n games
    Parameters:
    series (pd.Series, numeric): This is the result variable for calculating WR
    n (int): This is the number of games to calculate the WR for

    Returns:
    wr: A float, WR over the last n games
  '''
  series_shift = series.shift(1)
  wins = series_shift.rolling(window=n, min_periods=0).sum()
  games = series_shift.rolling(window=n, min_periods=0).count()
  wr = wins / games

  return wr

# Function to calculate team performance in last n games
def gen_last_n(df, n):
  '''Calculate winrate for last n games
    Parameters:
    df (pd.DataFrame): This is the input df containing variables to calculate
    n (int): This is the number of games to calculate variables for

    Returns:
    df: A pandas DF with the new last n variables added
  '''
  # Select variables to calculate and initialize DF
  vars = ['pts_tot', 'fg_pct', 'ft_pct', 'fg3_pct', 'ast', 'reb', 'tov', 'spread']
  df = df.sort_values(by=['team_id', 'game_date'])
  # Overall stats
  for var in vars:
    df[var + '_last' + str(n)] = df.groupby('team_id')[var].apply(lambda x: mean_last_n(x, n)).reset_index(level=0, drop=True)
  df['wr_last' + str(n)] = df.groupby('team_id')['result'].apply(lambda x: wr_last_n(x, n)).reset_index(level=0, drop=True)
  # Home stats
  for var in vars:
    df[var + '_last' + str(n) + "_home"] = df[df['location'] == 'home'].groupby('team_id')[var].apply(lambda x: mean_last_n(x, n)).reset_index(level=0, drop=True)
  df['wr_last' + str(n) + "_home"] = df[df['location'] == 'home'].groupby('team_id')['result'].apply(lambda x: wr_last_n(x, n)).reset_index(level=0, drop=True)
  # Away stats
  for var in vars:
    df[var + '_last' + str(n) + "_away"] = df[df['location'] == 'away'].groupby('team_id')[var].apply(lambda x: mean_last_n(x, n)).reset_index(level=0, drop=True)
  df['wr_last' + str(n) + "_away"] = df[df['location'] == 'away'].groupby('team_id')['result'].apply(lambda x: wr_last_n(x, n)).reset_index(level=0, drop=True)
  # Consolidate locations
  for var in ['pts_tot', 'fg_pct', 'ft_pct', 'fg3_pct', 'ast', 'reb', 'tov', 'spread', 'wr']:
    # Use the original DataFrame index to access home and away stats
    df[var + '_last' + str(n) + '_loc'] = df.apply(lambda row: row[var + '_last' + str(n) + '_home'] if row['location'] == 'home' else row[var + '_last' + str(n) + '_away'], axis=1)
    df = df.drop([var + '_last' + str(n) + '_home', var + '_last' + str(n) + '_away'], axis=1)

  return df

# %%
# Calculate team performance in last 10/20/50 games
combined_df = gen_last_n(combined_df, 10)
combined_df = gen_last_n(combined_df, 20)
combined_df = gen_last_n(combined_df, 50)

# Sort data
combined_df = combined_df.sort_values(by=['season', 'game_date', 'game_id', 'location']).reset_index(drop=True)

# %%
# Check proper performance variable processing of a data sample
combined_df[combined_df['team_abbr'] == "ATL"][['team_abbr', 'game_date', 'location', 'tov',
                                                'tov_last50', 'tov_last10', 'tov_last20',
                                                'tov_last50_loc', 'tov_last10_loc', 'tov_last20_loc',
                                                'days_since_last_game', 'consecutive_away_games']].head(20)
# Out:
#     team_abbr  game_date location  tov  tov_last50  tov_last10  tov_last20  \
# 33        ATL 2012-11-02     home   13         NaN         NaN         NaN
# 76        ATL 2012-11-04     away   10   13.000000   13.000000   13.000000
# 107       ATL 2012-11-07     home   17   11.500000   11.500000   11.500000
# 141       ATL 2012-11-09     home   13   13.333333   13.333333   13.333333
# 178       ATL 2012-11-11     away   22   13.250000   13.250000   13.250000
# 200       ATL 2012-11-12     away   16   15.000000   15.000000   15.000000
# 232       ATL 2012-11-14     away   12   15.166667   15.166667   15.166667
# 252       ATL 2012-11-16     away   15   14.714286   14.714286   14.714286
# 295       ATL 2012-11-19     home   13   14.750000   14.750000   14.750000
# 321       ATL 2012-11-21     home   13   14.555556   14.555556   14.555556
# 338       ATL 2012-11-23     away   21   14.400000   14.400000   14.400000
# 367       ATL 2012-11-24     home   18   15.000000   15.200000   15.000000
# 423       ATL 2012-11-28     home    9   15.250000   16.000000   15.250000
# 453       ATL 2012-11-30     home   12   14.769231   15.200000   14.769231
# 519       ATL 2012-12-05     home   14   14.571429   15.100000   14.571429
# 545       ATL 2012-12-07     home   14   14.533333   14.300000   14.533333
# 576       ATL 2012-12-08     away   14   14.500000   14.100000   14.500000
# 598       ATL 2012-12-10     away   14   14.470588   14.300000   14.470588
# 618       ATL 2012-12-12     away   14   14.444444   14.200000   14.444444
# 643       ATL 2012-12-13     home   13   14.421053   14.300000   14.421053
#
#      tov_last50_loc  tov_last10_loc  tov_last20_loc  days_since_last_game  \
# 33              NaN             NaN             NaN                   5.0
# 76              NaN             NaN             NaN                   2.0
# 107       13.000000       13.000000       13.000000                   3.0
# 141       15.000000       15.000000       15.000000                   2.0
# 178       10.000000       10.000000       10.000000                   2.0
# 200       16.000000       16.000000       16.000000                   1.0
# 232       16.000000       16.000000       16.000000                   2.0
# 252       15.000000       15.000000       15.000000                   2.0
# 295       14.333333       14.333333       14.333333                   3.0
# 321       14.000000       14.000000       14.000000                   2.0
# 338       15.000000       15.000000       15.000000                   2.0
# 367       13.800000       13.800000       13.800000                   1.0
# 423       14.500000       14.500000       14.500000                   4.0
# 453       13.714286       13.714286       13.714286                   2.0
# 519       13.500000       13.500000       13.500000                   5.0
# 545       13.555556       13.555556       13.555556                   2.0
# 576       16.000000       16.000000       16.000000                   1.0
# 598       15.714286       15.714286       15.714286                   2.0
# 618       15.500000       15.500000       15.500000                   2.0
# 643       13.600000       13.600000       13.600000                   1.0
#
#      consecutive_away_games
# 33                        0
# 76                        1
# 107                       0
# 141                       0
# 178                       1
# 200                       2
# 232                       3
# 252                       4
# 295                       0
# 321                       0
# 338                       1
# 367                       0
# 423                       0
# 453                       0
# 519                       0
# 545                       0
# 576                       1
# 598                       2
# 618                       3
# 643                       0

# %%
# Drop early games without historical performance data - should be 30 * 2 games for each team
print("Before:", combined_df.shape)
combined_df = combined_df.dropna()
print("After:", combined_df.shape)
# Out:
# Before: (17204, 81)
# After: (17144, 81)

# %% [markdown]
# ## EDA

# %%
# Distribution of total points scored
plt.figure(figsize=(10, 6))
sns.histplot(combined_df['pts_tot'], kde=True)
plt.title('Distribution of Total Points Scored')
plt.xlabel('Total Points')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot of points scored by each quarter
plt.figure(figsize=(12, 6))
sns.boxplot(data=combined_df[['pts_q1', 'pts_q2', 'pts_q3', 'pts_q4']])
plt.title('Boxplot of Points Scored by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Points')
plt.show()

# %%
# Team-wise points comparison
plt.figure(figsize=(14, 8))
sns.boxplot(x='team_abbr', y='pts_tot', data=combined_df)
plt.title('Team-wise Total Points Comparison')
plt.xlabel('Team')
plt.ylabel('Total Points')
plt.xticks(rotation=90)
plt.show()

# %%
# Top scoring teams
top_teams = combined_df.groupby('team_abbr')['pts_tot'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(14, 6))
sns.barplot(x=top_teams.index, y=top_teams.values)
plt.title('Top 10 Scoring Teams')
plt.xlabel('Team')
plt.ylabel('Total Points')
plt.show()

# %%
# Boxplot of points for winning and losing teams
plt.figure(figsize=(12, 6))
sns.boxplot(x='result', y='pts_tot', data=combined_df)
plt.title('Points Distribution for Winning and Losing Teams')
plt.xlabel('Win/Loss')
plt.ylabel('Total Points')
plt.show()

# %%
# Scatter plot of assists vs. points
plt.figure(figsize=(10, 6))
sns.scatterplot(x='ast', y='pts_tot', data=combined_df)
plt.title('Assists vs. Total Points')
plt.xlabel('Assists')
plt.ylabel('Total Points')
plt.show()

# %%
# Scatter plot of rebounds vs. points
plt.figure(figsize=(10, 6))
sns.scatterplot(x='reb', y='pts_tot', data=combined_df)
plt.title('Rebounds vs. Total Points')
plt.xlabel('Rebounds')
plt.ylabel('Total Points')
plt.show()

# %%
# Generate consolidated DF for correlation heatmap
consolidated_df = combined_df.filter(['vegas_spread', 'spread', 'pts_tot_last10', 'fg_pct_last10',
                                      'ft_pct_last10', 'fg3_pct_last10' 'ast_last10', 'reb_last10',
                                      'tov_last10', 'spread_last10', 'wr_last10', 'pts_tot_last10_loc',
                                      'fg_pct_last10_loc', 'ft_pct_last10_loc', 'fg3_pct_last10_loc',
                                      'ast_last10_loc', 'reb_last10_loc', 'tov_last10_loc',
                                      'spread_last10_loc', 'wr_last10_loc', 'days_since_last_game',
                                      'consecutive_away_games'])

# Correlation heatmap
plt.figure(figsize=(16, 10))
numeric_cols = consolidated_df.select_dtypes(include=['float64', 'int64']).columns
sns.heatmap(consolidated_df[numeric_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Additional pre-processing

# %% [markdown]
# ### Reshape and generate covered spread class variable

# %%
# Drop current-game variables not used for prediction
combined_df = combined_df.drop(['pts_q1', 'pts_q2','pts_q3', 'pts_q4', 'pts_ot1',
                                'pts_ot2', 'pts_ot3', 'pts_ot4', 'pts_tot', 'fg_pct',
                                'ft_pct', 'fg3_pct', 'ast', 'reb', 'tov', 'result'],
                                axis=1)

# Reshape wide on game level
cols_to_pivot = ['team_abbr', 'vegas_spread', 'spread', 'days_since_last_game', 'consecutive_away_games',
                 'pts_tot_last50', 'fg_pct_last50', 'ft_pct_last50', 'fg3_pct_last50', 'ast_last50',
                 'reb_last50', 'tov_last50', 'spread_last50', 'wr_last50', 'pts_tot_last10',
                 'fg_pct_last10', 'ft_pct_last10', 'fg3_pct_last10', 'ast_last10',
                 'reb_last10', 'tov_last10', 'spread_last10', 'wr_last10', 'pts_tot_last20',
                 'fg_pct_last20', 'ft_pct_last20', 'fg3_pct_last20', 'ast_last20',
                 'reb_last20', 'tov_last20', 'spread_last20', 'wr_last20', 'pts_tot_last10_loc',
                 'fg_pct_last10_loc', 'ft_pct_last10_loc', 'fg3_pct_last10_loc',
                 'ast_last10_loc', 'reb_last10_loc', 'tov_last10_loc',
                 'spread_last10_loc', 'wr_last10_loc', 'pts_tot_last20_loc',
                 'fg_pct_last20_loc', 'ft_pct_last20_loc', 'fg3_pct_last20_loc',
                 'ast_last20_loc', 'reb_last20_loc', 'tov_last20_loc',
                 'spread_last20_loc', 'wr_last20_loc', 'pts_tot_last50_loc',
                 'fg_pct_last50_loc', 'ft_pct_last50_loc', 'fg3_pct_last50_loc',
                 'ast_last50_loc', 'reb_last50_loc', 'tov_last50_loc',
                 'spread_last50_loc', 'wr_last50_loc', 'spread_odds']
game_df = combined_df.pivot(index=['game_id', 'game_date', 'season'], columns='location', values=cols_to_pivot)

# Flatten columns
game_df.columns = ['_'.join(col).strip() for col in game_df.columns.values]

# Drop away spreads and home consecutive away count
game_df = game_df.drop(['vegas_spread_away', 'spread_away', 'consecutive_away_games_home', 'spread_odds_away'], axis=1)

# Rename columns
game_df = game_df.rename(columns={'game_id_': 'game_id',
                                  'game_date_': 'game_date',
                                  'season_': 'season',
                                  'vegas_spread_home': 'vegas_spread',
                                  'spread_home': 'spread',
                                  'consecutive_away_games_away': 'consecutive_away_games',
                                  'spread_odds_home': 'spread_odds'})

# Reset index
game_df = game_df.reset_index()

# Inspect data
game_df.head()

# Some games only have information for one team - drop these games
game_df = game_df.dropna()

# Reset index
game_df = game_df.reset_index(drop = True)

# Classify actual spread against Vegas spread
game_df['spread_sign'] = ['negative' if x < 0 else 'positive' for x in game_df['vegas_spread']]
game_df['covered_spread'] = [0 if x == 'negative' and y > z or x == 'positive' and y < z else 1 for x, y, z in zip(game_df['spread_sign'], game_df['spread'], game_df['vegas_spread'])]
game_df = game_df.drop(['spread_sign'], axis=1)

# Convert odds to payout ratio
game_df['spread_odds'] = game_df.apply(lambda row: -100/row['spread_odds'] if row['spread_odds'] < 0 else row['spread_odds']/100, axis=1)

# Inspect data
game_df.head()
# Out:
#     game_id  game_date   season team_abbr_away team_abbr_home vegas_spread  \
# 0  21200013 2012-11-26  2012-13            NYK            BKN         1.17
# 1  21200030 2012-11-03  2012-13            DEN            MIA        -8.42
# 2  21200035 2012-11-03  2012-13            UTA            SAS         -7.5
# 3  21200036 2012-11-03  2012-13            GSW            LAC        -8.42
# 4  21200041 2012-11-04  2012-13            DET            LAL        -7.92
#
#   spread days_since_last_game_away days_since_last_game_home  \
# 0   -7.0                       1.0                       1.0
# 1   -3.0                       1.0                       1.0
# 2  -10.0                       1.0                       2.0
# 3    4.0                       1.0                       1.0
# 4  -29.0                       2.0                       2.0
#
#   consecutive_away_games pts_tot_last50_away pts_tot_last50_home  \
# 0                      1          103.416667           95.583333
# 1                      3                82.0               102.0
# 2                      2                99.5                92.5
# 3                      1                90.5               103.0
# 4                      2                92.5           97.333333
#
#   fg_pct_last50_away fg_pct_last50_home ft_pct_last50_away ft_pct_last50_home  \
# 0           0.458417           0.449583           0.783917           0.723083
# 1              0.378             0.5045              0.561             0.8295
# 2             0.4195              0.459              0.619              0.671
# 3              0.417              0.483              0.701              0.734
# 4              0.427              0.498              0.674              0.638
#
#   fg3_pct_last50_away fg3_pct_last50_home ast_last50_away ast_last50_home  \
# 0            0.405833            0.326667       20.416667       21.666667
# 1              0.2455               0.425            20.5            21.5
# 2               0.393              0.2815            21.5            24.5
# 3               0.397              0.3485            20.0            24.5
# 4              0.3415               0.371            20.5            20.0
#
#   reb_last50_away reb_last50_home tov_last50_away tov_last50_home  \
# 0            39.5       41.333333           10.75       13.083333
# 1            49.5            38.5            17.0            14.5
# 2            52.5            41.0            14.0            14.0
# 3            42.5            38.0            18.0            16.5
# 4            37.5            43.0            12.5       19.333333
#
#   spread_last50_away spread_last50_home wr_last50_away wr_last50_home  \
# 0               -8.0          -4.083333           0.75       0.666667
# 1               11.0                3.5            0.0            0.5
# 2               -8.5               -3.0            0.5            1.0
# 3                4.0               -9.5            0.5            1.0
# 4                6.0           9.333333            0.0            0.0
#
#   pts_tot_last10_away pts_tot_last10_home fg_pct_last10_away  \
# 0               103.7                94.4             0.4566
# 1                82.0               102.0              0.378
# 2                99.5                92.5             0.4195
# 3                90.5               103.0              0.417
# 4                92.5           97.333333              0.427
#
#   fg_pct_last10_home ft_pct_last10_away ft_pct_last10_home  \
# 0             0.4459             0.7929             0.7225
# 1             0.5045              0.561             0.8295
# 2              0.459              0.619              0.671
# 3              0.483              0.701              0.734
# 4              0.498              0.674              0.638
#
#   fg3_pct_last10_away fg3_pct_last10_home ast_last10_away ast_last10_home  \
# 0              0.3935              0.2955            20.0            21.6
# 1              0.2455               0.425            20.5            21.5
# 2               0.393              0.2815            21.5            24.5
# 3               0.397              0.3485            20.0            24.5
# 4              0.3415               0.371            20.5            20.0
#
#   reb_last10_away reb_last10_home tov_last10_away tov_last10_home  \
# 0            39.4            42.6            10.3            12.7
# 1            49.5            38.5            17.0            14.5
# 2            52.5            41.0            14.0            14.0
# 3            42.5            38.0            18.0            16.5
# 4            37.5            43.0            12.5       19.333333
#
#   spread_last10_away spread_last10_home wr_last10_away wr_last10_home  \
# 0               -6.0               -5.3            0.7            0.7
# 1               11.0                3.5            0.0            0.5
# 2               -8.5               -3.0            0.5            1.0
# 3                4.0               -9.5            0.5            1.0
# 4                6.0           9.333333            0.0            0.0
#
#   pts_tot_last20_away pts_tot_last20_home fg_pct_last20_away  \
# 0          103.416667           95.583333           0.458417
# 1                82.0               102.0              0.378
# 2                99.5                92.5             0.4195
# 3                90.5               103.0              0.417
# 4                92.5           97.333333              0.427
#
#   fg_pct_last20_home ft_pct_last20_away ft_pct_last20_home  \
# 0           0.449583           0.783917           0.723083
# 1             0.5045              0.561             0.8295
# 2              0.459              0.619              0.671
# 3              0.483              0.701              0.734
# 4              0.498              0.674              0.638
#
#   fg3_pct_last20_away fg3_pct_last20_home ast_last20_away ast_last20_home  \
# 0            0.405833            0.326667       20.416667       21.666667
# 1              0.2455               0.425            20.5            21.5
# 2               0.393              0.2815            21.5            24.5
# 3               0.397              0.3485            20.0            24.5
# 4              0.3415               0.371            20.5            20.0
#
#   reb_last20_away reb_last20_home tov_last20_away tov_last20_home  \
# 0            39.5       41.333333           10.75       13.083333
# 1            49.5            38.5            17.0            14.5
# 2            52.5            41.0            14.0            14.0
# 3            42.5            38.0            18.0            16.5
# 4            37.5            43.0            12.5       19.333333
#
#   spread_last20_away spread_last20_home wr_last20_away wr_last20_home  \
# 0               -8.0          -4.083333           0.75       0.666667
# 1               11.0                3.5            0.0            0.5
# 2               -8.5               -3.0            0.5            1.0
# 3                4.0               -9.5            0.5            1.0
# 4                6.0           9.333333            0.0            0.0
#
#   pts_tot_last10_loc_away pts_tot_last10_loc_home fg_pct_last10_loc_away  \
# 0              103.428571               97.857143               0.471571
# 1                    82.0                   120.0                  0.378
# 2                    86.0                    86.0                  0.412
# 3                    87.0                   101.0                  0.384
# 4                    89.0                    93.0                  0.411
#
#   fg_pct_last10_loc_home ft_pct_last10_loc_away ft_pct_last10_loc_home  \
# 0               0.452429               0.793286               0.731714
# 1                  0.544                  0.561                  0.813
# 2                  0.443                    0.5                  0.688
# 3                  0.514                  0.696                   0.69
# 4                  0.497                  0.579                 0.5505
#
#   fg3_pct_last10_loc_away fg3_pct_last10_loc_home ast_last10_loc_away  \
# 0                0.396571                   0.361                20.0
# 1                  0.2455                     0.5                20.5
# 2                   0.357                   0.263                19.0
# 3                   0.294                   0.333                19.0
# 4                   0.308                  0.3345                20.0
#
#   ast_last10_loc_home reb_last10_loc_away reb_last10_loc_home  \
# 0           22.142857                38.0                42.0
# 1                25.0                49.5                36.0
# 2                27.0                44.0                39.0
# 3                25.0                49.0                39.0
# 4                19.5                39.0                42.0
#
#   tov_last10_loc_away tov_last10_loc_home spread_last10_loc_away  \
# 0           10.714286           13.714286              -2.428571
# 1                17.0                 8.0                   11.0
# 2                14.0                13.0                    2.0
# 3                18.0                22.0                   -2.0
# 4                 9.0                17.0                    3.0
#
#   spread_last10_loc_home wr_last10_loc_away wr_last10_loc_home  \
# 0              -6.428571           0.571429           0.857143
# 1                  -13.0                0.0                1.0
# 2                   -2.0                0.0                1.0
# 3                   -9.0                1.0                1.0
# 4                    9.0                0.0                0.0
#
#   pts_tot_last20_loc_away pts_tot_last20_loc_home fg_pct_last20_loc_away  \
# 0              103.428571               97.857143               0.471571
# 1                    82.0                   120.0                  0.378
# 2                    86.0                    86.0                  0.412
# 3                    87.0                   101.0                  0.384
# 4                    89.0                    93.0                  0.411
#
#   fg_pct_last20_loc_home ft_pct_last20_loc_away ft_pct_last20_loc_home  \
# 0               0.452429               0.793286               0.731714
# 1                  0.544                  0.561                  0.813
# 2                  0.443                    0.5                  0.688
# 3                  0.514                  0.696                   0.69
# 4                  0.497                  0.579                 0.5505
#
#   fg3_pct_last20_loc_away fg3_pct_last20_loc_home ast_last20_loc_away  \
# 0                0.396571                   0.361                20.0
# 1                  0.2455                     0.5                20.5
# 2                   0.357                   0.263                19.0
# 3                   0.294                   0.333                19.0
# 4                   0.308                  0.3345                20.0
#
#   ast_last20_loc_home reb_last20_loc_away reb_last20_loc_home  \
# 0           22.142857                38.0                42.0
# 1                25.0                49.5                36.0
# 2                27.0                44.0                39.0
# 3                25.0                49.0                39.0
# 4                19.5                39.0                42.0
#
#   tov_last20_loc_away tov_last20_loc_home spread_last20_loc_away  \
# 0           10.714286           13.714286              -2.428571
# 1                17.0                 8.0                   11.0
# 2                14.0                13.0                    2.0
# 3                18.0                22.0                   -2.0
# 4                 9.0                17.0                    3.0
#
#   spread_last20_loc_home wr_last20_loc_away wr_last20_loc_home  \
# 0              -6.428571           0.571429           0.857143
# 1                  -13.0                0.0                1.0
# 2                   -2.0                0.0                1.0
# 3                   -9.0                1.0                1.0
# 4                    9.0                0.0                0.0
#
#   pts_tot_last50_loc_away pts_tot_last50_loc_home fg_pct_last50_loc_away  \
# 0              103.428571               97.857143               0.471571
# 1                    82.0                   120.0                  0.378
# 2                    86.0                    86.0                  0.412
# 3                    87.0                   101.0                  0.384
# 4                    89.0                    93.0                  0.411
#
#   fg_pct_last50_loc_home ft_pct_last50_loc_away ft_pct_last50_loc_home  \
# 0               0.452429               0.793286               0.731714
# 1                  0.544                  0.561                  0.813
# 2                  0.443                    0.5                  0.688
# 3                  0.514                  0.696                   0.69
# 4                  0.497                  0.579                 0.5505
#
#   fg3_pct_last50_loc_away fg3_pct_last50_loc_home ast_last50_loc_away  \
# 0                0.396571                   0.361                20.0
# 1                  0.2455                     0.5                20.5
# 2                   0.357                   0.263                19.0
# 3                   0.294                   0.333                19.0
# 4                   0.308                  0.3345                20.0
#
#   ast_last50_loc_home reb_last50_loc_away reb_last50_loc_home  \
# 0           22.142857                38.0                42.0
# 1                25.0                49.5                36.0
# 2                27.0                44.0                39.0
# 3                25.0                49.0                39.0
# 4                19.5                39.0                42.0
#
#   tov_last50_loc_away tov_last50_loc_home spread_last50_loc_away  \
# 0           10.714286           13.714286              -2.428571
# 1                17.0                 8.0                   11.0
# 2                14.0                13.0                    2.0
# 3                18.0                22.0                   -2.0
# 4                 9.0                17.0                    3.0
#
#   spread_last50_loc_home wr_last50_loc_away wr_last50_loc_home  spread_odds  \
# 0              -6.428571           0.571429           0.857143     0.923105
# 1                  -13.0                0.0                1.0     0.920217
# 2                   -2.0                0.0                1.0     0.913242
# 3                   -9.0                1.0                1.0     0.917431
# 4                    9.0                0.0                0.0     0.904977
#
#    covered_spread
# 0               0
# 1               0
# 2               1
# 3               0
# 4               1

# %%
# Inspect covered spread class balance
game_df['covered_spread'].value_counts()
# Out:
# covered_spread
# 0    4289
# 1    4271
# Name: count, dtype: int64

# %%
# Describe data
game_df = game_df.infer_objects()
game_df['game_id'] = game_df['game_id'].astype(str)
game_df.describe()
# Out:
#                            game_date  vegas_spread       spread  \
# count                           8560   8560.000000  8560.000000
# mean   2016-01-23 22:01:03.925233408     -2.814792    -2.689369
# min              2012-11-03 00:00:00    -21.580000   -61.000000
# 25%              2014-03-11 00:00:00     -7.670000   -11.000000
# 50%              2016-01-20 00:00:00     -3.670000    -4.000000
# 75%              2017-11-30 00:00:00      2.580000     7.000000
# max              2019-04-10 00:00:00     17.330000    56.000000
# std                              NaN      6.583119    13.583291
#
#        days_since_last_game_away  days_since_last_game_home  \
# count                8560.000000                8560.000000
# mean                    1.979206                   2.206659
# min                     1.000000                   1.000000
# 25%                     1.000000                   2.000000
# 50%                     2.000000                   2.000000
# 75%                     2.000000                   2.000000
# max                     5.000000                   5.000000
# std                     0.864611                   0.837785
#
#        consecutive_away_games  pts_tot_last50_away  pts_tot_last50_home  \
# count             8560.000000          8560.000000          8560.000000
# mean                 1.955958           102.931915           102.904316
# min                  0.000000            82.000000            83.500000
# 25%                  1.000000            98.840000            98.760000
# 50%                  2.000000           102.700000           102.680000
# 75%                  3.000000           106.520000           106.540000
# max                  9.000000           119.660000           119.540000
# std                  1.276130             5.733492             5.719999
#
#        fg_pct_last50_away  fg_pct_last50_home  ft_pct_last50_away  \
# count         8560.000000         8560.000000         8560.000000
# mean             0.455647            0.455498            0.760397
# min              0.373333            0.396250            0.561000
# 25%              0.444876            0.444760            0.741960
# 50%              0.454430            0.454240            0.763240
# 75%              0.466960            0.466677            0.783160
# max              0.518600            0.518750            0.853120
# std              0.017030            0.016935            0.032220
#
#        ft_pct_last50_home  fg3_pct_last50_away  fg3_pct_last50_home  \
# count         8560.000000          8560.000000          8560.000000
# mean             0.760645             0.355015             0.354655
# min              0.623200             0.211667             0.267125
# 25%              0.742180             0.342200             0.341800
# 50%              0.763350             0.354680             0.354110
# 75%              0.782960             0.367760             0.367460
# max              0.852140             0.524000             0.493250
# std              0.031756             0.021544             0.021461
#
#        ast_last50_away  ast_last50_home  reb_last50_away  reb_last50_home  \
# count      8560.000000      8560.000000      8560.000000      8560.000000
# mean         22.559566        22.536025        43.320360        43.295487
# min          16.000000        15.600000        35.200000        35.833333
# 25%          21.120000        21.082500        41.960000        41.920000
# 50%          22.400000        22.400000        43.340000        43.320000
# 75%          23.720000        23.680000        44.720000        44.720000
# max          31.380000        31.300000        55.000000        53.000000
# std           2.103893         2.103170         2.114696         2.110890
#
#        tov_last50_away  tov_last50_home  spread_last50_away  \
# count      8560.000000      8560.000000         8560.000000
# mean         13.789300        13.789639           -0.027803
# min           9.666667        10.000000          -17.000000
# 25%          13.020000        13.040000           -3.320000
# 50%          13.780000        13.760000           -0.040000
# 75%          14.520000        14.520000            3.220000
# max          19.250000        19.666667           13.780000
# std           1.172182         1.179195            4.791518
#
#        spread_last50_home  wr_last50_away  wr_last50_home  \
# count         8560.000000     8560.000000     8560.000000
# mean             0.029394        0.500937        0.499213
# min            -19.333333        0.000000        0.000000
# 25%             -3.280000        0.380000        0.380000
# 50%              0.057778        0.500000        0.500000
# 75%              3.200000        0.620000        0.620000
# max             13.940000        1.000000        1.000000
# std              4.778900        0.160030        0.159603
#
#        pts_tot_last10_away  pts_tot_last10_home  fg_pct_last10_away  \
# count          8560.000000          8560.000000         8560.000000
# mean            103.473402           103.403311            0.456263
# min              82.000000            83.500000            0.373333
# 25%              98.500000            98.400000            0.440800
# 50%             103.200000           103.300000            0.455800
# 75%             108.100000           108.000000            0.471500
# max             131.100000           129.100000            0.531800
# std               6.943978             6.909821            0.023005
#
#        fg_pct_last10_home  ft_pct_last10_away  ft_pct_last10_home  \
# count         8560.000000         8560.000000         8560.000000
# mean             0.455972            0.760960            0.761279
# min              0.376100            0.561000            0.581200
# 25%              0.440300            0.732700            0.732900
# 50%              0.455900            0.763900            0.764200
# 75%              0.471100            0.792500            0.791400
# max              0.535000            0.889200            0.900600
# std              0.022922            0.043545            0.043535
#
#        fg3_pct_last10_away  fg3_pct_last10_home  ast_last10_away  \
# count          8560.000000          8560.000000      8560.000000
# mean              0.355166             0.354768        22.684298
# min               0.211667             0.214000        15.600000
# 25%               0.332000             0.332400        20.900000
# 50%               0.355700             0.354600        22.500000
# 75%               0.377800             0.377100        24.300000
# max               0.524000             0.493250        34.400000
# std               0.035052             0.035069         2.626540
#
#        ast_last10_home  reb_last10_away  reb_last10_home  tov_last10_away  \
# count      8560.000000      8560.000000      8560.000000      8560.000000
# mean         22.654977        43.430962        43.402276        13.746377
# min          15.600000        32.700000        33.400000         7.200000
# 25%          20.900000        41.500000        41.500000        12.600000
# 50%          22.400000        43.400000        43.400000        13.700000
# 75%          24.200000        45.300000        45.300000        14.800000
# max          34.100000        55.000000        53.900000        19.900000
# std           2.606494         2.878348         2.870542         1.629675
#
#        tov_last10_home  spread_last10_away  spread_last10_home  \
# count      8560.000000         8560.000000         8560.000000
# mean         13.742448           -0.033835            0.033954
# min           7.500000          -20.600000          -20.700000
# 25%          12.600000           -4.300000           -4.200000
# 50%          13.700000            0.000000            0.000000
# 75%          14.800000            4.200000            4.200000
# max          20.100000           20.900000           22.800000
# std           1.624040            6.225930            6.221402
#
#        wr_last10_away  wr_last10_home  pts_tot_last20_away  \
# count      8560.00000     8560.000000          8560.000000
# mean          0.50029        0.499881           103.347310
# min           0.00000        0.000000            82.000000
# 25%           0.30000        0.300000            98.700000
# 50%           0.50000        0.500000           103.100000
# 75%           0.70000        0.700000           107.500000
# max           1.00000        1.000000           125.550000
# std           0.21140        0.210613             6.345527
#
#        pts_tot_last20_home  fg_pct_last20_away  fg_pct_last20_home  \
# count          8560.000000         8560.000000         8560.000000
# mean            103.266931            0.456131            0.455821
# min              83.500000            0.373333            0.396250
# 25%              98.650000            0.443148            0.442750
# 50%             103.000000            0.455575            0.455250
# 75%             107.312500            0.468762            0.468250
# max             125.250000            0.520700            0.518750
# std               6.322243            0.019629            0.019381
#
#        ft_pct_last20_away  ft_pct_last20_home  fg3_pct_last20_away  \
# count         8560.000000         8560.000000          8560.000000
# mean             0.760874            0.761042             0.355146
# min              0.561000            0.617050             0.211667
# 25%              0.737950            0.737900             0.337296
# 50%              0.762975            0.763400             0.355000
# 75%              0.787112            0.787000             0.372150
# max              0.878750            0.872800             0.524000
# std              0.037308            0.037273             0.027525
#
#        fg3_pct_last20_home  ast_last20_away  ast_last20_home  reb_last20_away  \
# count          8560.000000      8560.000000      8560.000000      8560.000000
# mean              0.354667        22.648881        22.628035        43.400651
# min               0.262150        16.000000        15.600000        34.600000
# 25%               0.337350        21.050000        21.050000        41.800000
# 50%               0.354400        22.450000        22.450000        43.450000
# 75%               0.371650        24.000000        24.000000        45.000000
# max               0.493250        32.550000        32.900000        55.000000
# std               0.027395         2.355610         2.358370         2.483518
#
#        reb_last20_home  tov_last20_away  tov_last20_home  spread_last20_away  \
# count      8560.000000      8560.000000      8560.000000         8560.000000
# mean         43.371997        13.760172        13.758937           -0.052256
# min          34.550000         8.450000         8.950000          -18.350000
# 25%          41.750000        12.800000        12.850000           -3.600000
# 50%          43.400000        13.750000        13.750000           -0.100000
# 75%          45.012500        14.600000        14.600000            3.650000
# max          53.000000        19.250000        19.666667           18.600000
# std           2.468388         1.383178         1.366926            5.420265
#
#        spread_last20_home  wr_last20_away  wr_last20_home  \
# count         8560.000000     8560.000000     8560.000000
# mean             0.051423        0.500961        0.499239
# min            -19.333333        0.000000        0.000000
# 25%             -3.555357        0.350000        0.350000
# 50%             -0.050000        0.500000        0.500000
# 75%              3.750000        0.650000        0.650000
# max             17.750000        1.000000        1.000000
# std              5.396322        0.181558        0.181766
#
#        pts_tot_last10_loc_away  pts_tot_last10_loc_home  \
# count              8560.000000              8560.000000
# mean                101.935429               104.656759
# min                  73.000000                81.666667
# 25%                  97.300000                99.700000
# 50%                 101.700000               104.500000
# 75%                 106.300000               109.300000
# max                 125.200000               126.900000
# std                   6.695824                 6.954583
#
#        fg_pct_last10_loc_away  fg_pct_last10_loc_home  ft_pct_last10_loc_away  \
# count             8560.000000             8560.000000             8560.000000
# mean                 0.450390                0.461550                0.760049
# min                  0.356000                0.345000                0.500000
# 25%                  0.436300                0.445400                0.731800
# 50%                  0.449600                0.461200                0.762100
# 75%                  0.464500                0.477925                0.792100
# max                  0.638000                0.614000                1.000000
# std                  0.021371                0.024820                0.044878
#
#        ft_pct_last10_loc_home  fg3_pct_last10_loc_away  \
# count             8560.000000              8560.000000
# mean                 0.761792                 0.349906
# min                  0.550500                 0.143000
# 25%                  0.734700                 0.327800
# 50%                  0.764100                 0.350000
# 75%                  0.792400                 0.372300
# max                  0.889000                 0.491200
# std                  0.043899                 0.034226
#
#        fg3_pct_last10_loc_home  ast_last10_loc_away  ast_last10_loc_home  \
# count              8560.000000          8560.000000          8560.000000
# mean                  0.359852            22.035523            23.232166
# min                   0.118000            12.000000            13.000000
# 25%                   0.335800            20.400000            21.300000
# 50%                   0.359100            21.900000            23.100000
# 75%                   0.384100            23.500000            24.900000
# max                   0.640000            34.000000            35.200000
# std                   0.037619             2.496664             2.797252
#
#        reb_last10_loc_away  reb_last10_loc_home  tov_last10_loc_away  \
# count          8560.000000          8560.000000          8560.000000
# mean             42.802176            43.963931            13.867322
# min              33.800000            30.000000             7.000000
# 25%              41.000000            42.000000            12.737500
# 50%              42.800000            44.000000            13.800000
# 75%              44.500000            45.900000            14.900000
# max              54.200000            67.000000            24.000000
# std               2.750510             2.942426             1.661175
#
#        tov_last10_loc_home  spread_last10_loc_away  spread_last10_loc_home  \
# count           8560.00000             8560.000000             8560.000000
# mean              13.65518                2.711204               -2.709990
# min                6.60000              -29.000000              -27.000000
# 25%               12.60000               -1.300000               -7.000000
# 50%               13.60000                2.800000               -2.900000
# 75%               14.60000                6.800000                1.700000
# max               22.00000               30.000000               18.000000
# std                1.56965                5.905562                6.327008
#
#        wr_last10_loc_away  wr_last10_loc_home  pts_tot_last20_loc_away  \
# count         8560.000000         8560.000000              8560.000000
# mean             0.412652            0.587589               101.663926
# min              0.000000            0.000000                73.000000
# 25%              0.300000            0.400000                97.450000
# 50%              0.400000            0.600000               101.414216
# 75%              0.600000            0.700000               105.650000
# max              1.000000            1.000000               121.000000
# std              0.204279            0.217553                 6.054850
#
#        pts_tot_last20_loc_home  fg_pct_last20_loc_away  \
# count              8560.000000             8560.000000
# mean                104.396160                0.450088
# min                  81.666667                0.356000
# 25%                 100.000000                0.438738
# 50%                 104.300000                0.449000
# 75%                 108.250000                0.461400
# max                 126.000000                0.638000
# std                   6.278043                0.018032
#
#        fg_pct_last20_loc_home  ft_pct_last20_loc_away  ft_pct_last20_loc_home  \
# count             8560.000000             8560.000000             8560.000000
# mean                 0.461284                0.759751                0.761479
# min                  0.345000                0.500000                0.550500
# 25%                  0.447700                0.737400                0.738387
# 50%                  0.460950                0.761400                0.763050
# 75%                  0.474650                0.786013                0.787500
# max                  0.614000                1.000000                0.889000
# std                  0.021560                0.038384                0.036992
#
#        fg3_pct_last20_loc_away  fg3_pct_last20_loc_home  ast_last20_loc_away  \
# count              8560.000000              8560.000000          8560.000000
# mean                  0.349699                 0.359961            21.969646
# min                   0.143000                 0.118000            12.000000
# 25%                   0.333300                 0.341550            20.500000
# 50%                   0.349750                 0.359500            21.850000
# 75%                   0.366200                 0.377800            23.250000
# max                   0.471000                 0.640000            34.000000
# std                   0.026703                 0.030324             2.206540
#
#        ast_last20_loc_home  reb_last20_loc_away  reb_last20_loc_home  \
# count          8560.000000          8560.000000          8560.000000
# mean             23.173573            42.754013            43.905253
# min              13.000000            34.550000            30.000000
# 25%              21.453409            41.300000            42.250000
# 50%              23.050000            42.750000            43.950000
# 75%              24.650000            44.200000            45.550000
# max              33.700000            52.000000            67.000000
# std               2.547015             2.308318             2.538831
#
#        tov_last20_loc_away  tov_last20_loc_home  spread_last20_loc_away  \
# count          8560.000000          8560.000000             8560.000000
# mean             13.895795            13.670365                2.724276
# min               7.000000             8.000000              -29.000000
# 25%              13.037500            12.800000               -0.850000
# 50%              13.850000            13.650000                2.850000
# 75%              14.750000            14.500000                6.235577
# max              24.000000            22.000000               30.000000
# std               1.417596             1.329428                5.110879
#
#        spread_last20_loc_home  wr_last20_loc_away  wr_last20_loc_home  \
# count             8560.000000         8560.000000         8560.000000
# mean                -2.722104            0.412251            0.588011
# min                -27.000000            0.000000            0.000000
# 25%                 -6.600000            0.300000            0.450000
# 50%                 -2.950000            0.400000            0.600000
# 75%                  1.000000            0.550000            0.700000
# max                 14.700000            1.000000            1.000000
# std                  5.579306            0.175705            0.188555
#
#        pts_tot_last50_loc_away  pts_tot_last50_loc_home  \
# count              8560.000000              8560.000000
# mean                100.964588               103.730720
# min                  73.000000                81.666667
# 25%                  96.958372                99.640000
# 50%                 101.040000               103.840000
# 75%                 104.560000               107.185000
# max                 115.800000               126.000000
# std                   5.397486                 5.532900
#
#        fg_pct_last50_loc_away  fg_pct_last50_loc_home  ft_pct_last50_loc_away  \
# count             8560.000000             8560.000000             8560.000000
# mean                 0.449406                0.460763                0.759269
# min                  0.356000                0.345000                0.500000
# 25%                  0.440553                0.448320                0.740356
# 50%                  0.448580                0.460270                0.760750
# 75%                  0.458940                0.472620                0.781265
# max                  0.638000                0.614000                1.000000
# std                  0.015616                0.019275                0.033227
#
#        ft_pct_last50_loc_home  fg3_pct_last50_loc_away  \
# count             8560.000000              8560.000000
# mean                 0.760690                 0.349129
# min                  0.550500                 0.143000
# 25%                  0.742820                 0.336920
# 50%                  0.764310                 0.349660
# 75%                  0.782040                 0.361343
# max                  0.889000                 0.471000
# std                  0.031198                 0.021039
#
#        fg3_pct_last50_loc_home  ast_last50_loc_away  ast_last50_loc_home  \
# count              8560.000000          8560.000000          8560.000000
# mean                  0.360311            21.819120            23.042367
# min                   0.118000            12.000000            13.000000
# 25%                   0.346220            20.560000            21.520000
# 50%                   0.359720            21.760000            22.881176
# 75%                   0.373560            22.960000            24.380000
# max                   0.640000            34.000000            32.220000
# std                   0.024905             1.883789             2.276090
#
#        reb_last50_loc_away  reb_last50_loc_home  tov_last50_loc_away  \
# count          8560.000000          8560.000000          8560.000000
# mean             42.630838            43.749913            13.941342
# min              35.000000            30.000000             7.000000
# 25%              41.360000            42.420000            13.200000
# 50%              42.666667            43.800000            13.920000
# 75%              43.860000            45.106531            14.700000
# max              52.000000            67.000000            24.000000
# std               1.885033             2.159456             1.232617
#
#        tov_last50_loc_home  spread_last50_loc_away  spread_last50_loc_home  \
# count          8560.000000             8560.000000             8560.000000
# mean             13.677159                2.751500               -2.755898
# min               8.000000              -29.000000              -27.000000
# 25%              12.880000               -0.361463               -6.100000
# 50%              13.680000                2.860000               -2.760000
# 75%              14.380000                5.885684                0.580000
# max              22.000000               30.000000               11.320000
# std               1.150995                4.510327                4.936042
#
#        wr_last50_loc_away  wr_last50_loc_home  spread_odds  covered_spread
# count         8560.000000         8560.000000  8560.000000     8560.000000
# mean             0.411193            0.589423     0.924633        0.498949
# min              0.000000            0.000000     0.356926        0.000000
# 25%              0.300000            0.468750     0.916003        0.000000
# 50%              0.400000            0.600000     0.924471        0.000000
# 75%              0.520000            0.700000     0.931706        1.000000
# max              1.000000            1.000000     1.366680        1.000000
# std              0.153976            0.166127     0.015857        0.500028

# %% [markdown]
# ### Scaling and dummies

# %%
# Scale data BY SEASON
# We avoid data leakage as the scaling is performed BY SEASON
numeric_cols = game_df.select_dtypes(include=['float64', 'int64']).columns
for col in numeric_cols:
  if col in ['covered_spread', 'spread_odds']:
    continue
  game_df[col] = game_df.groupby('season')[col].transform(lambda x: (x - x.mean()) / x.std())

# Select features
game_df = game_df.drop(['game_id', 'game_date', 'team_abbr_away'], axis = 1)

# One-hot encoding of location
game_df = pd.get_dummies(game_df, columns=['team_abbr_home'])

# Inspect data
game_df.head()
# Out:
#     season  vegas_spread    spread  days_since_last_game_away  \
# 0  2012-13      0.736625 -0.287521                  -1.065122
# 1  2012-13     -0.847440  0.015576                  -1.065122
# 2  2012-13     -0.695475 -0.514843                  -1.065122
# 3  2012-13     -0.847440  0.545996                  -1.065122
# 4  2012-13     -0.764851 -1.954554                   0.157605
#
#    days_since_last_game_home  consecutive_away_games  pts_tot_last50_away  \
# 0                  -1.467168               -0.753210             1.303361
# 1                  -1.467168                0.764719            -3.513372
# 2                  -0.285670                0.005755             0.422480
# 3                  -1.467168               -0.753210            -1.601672
# 4                  -0.285670                0.005755            -1.151861
#
#    pts_tot_last50_home  fg_pct_last50_away  fg_pct_last50_home  \
# 0            -0.465296            0.416065           -0.027660
# 1             0.976788           -3.535082            2.644613
# 2            -1.158245           -1.496045            0.430560
# 3             1.201528           -1.618878            1.598412
# 4            -0.072000           -1.127544            2.328320
#
#    ft_pct_last50_away  ft_pct_last50_home  fg3_pct_last50_away  \
# 0            0.814251           -0.863258             1.840124
# 1           -5.016667            2.017276            -3.840201
# 2           -3.499538           -2.273073             1.385461
# 3           -1.354633           -0.567760             1.527174
# 4           -2.060882           -3.166331            -0.439092
#
#    fg3_pct_last50_home  ast_last50_away  ast_last50_home  reb_last50_away  \
# 0            -0.930853        -0.899764        -0.127253        -1.270369
# 1             2.480529        -0.848237        -0.228544         3.299993
# 2            -2.497775        -0.229915         1.594690         4.671102
# 3            -0.173410        -1.157399         1.594690         0.100739
# 4             0.607160        -0.848237        -1.140160        -2.184442
#
#    reb_last50_home  tov_last50_away  tov_last50_home  spread_last50_away  \
# 0        -0.423925        -2.975356        -0.915161           -1.644282
# 1        -1.781297         2.532153         0.311173            2.252572
# 2        -0.583615        -0.111451        -0.121651           -1.746831
# 3        -2.020834         3.413355         2.042469            0.816889
# 4         0.374530        -1.433253         4.495138            1.227084
#
#    spread_last50_home  wr_last50_away  wr_last50_home  pts_tot_last10_away  \
# 0           -0.866558        1.433980        0.964676             1.029272
# 1            0.737220       -2.858957       -0.005884            -2.891803
# 2           -0.637447        0.003001        2.905796             0.270354
# 3           -2.012114        0.003001        2.905796            -1.355898
# 4            1.970895       -2.858957       -2.917563            -0.994509
#
#    pts_tot_last10_home  fg_pct_last10_away  fg_pct_last10_home  \
# 0            -0.658945            0.137808           -0.312314
# 1             0.713299           -3.038552            2.046125
# 2            -1.002006           -1.361466            0.214914
# 3             0.893857           -1.462495            1.180827
# 4            -0.129307           -1.058378            1.784523
#
#    ft_pct_last10_away  ft_pct_last10_home  fg3_pct_last10_away  \
# 0            0.862372           -0.699088             0.951702
# 1           -4.212054            1.654491            -2.733443
# 2           -2.942900           -1.831885             0.939252
# 3           -1.148580           -0.446133             1.038850
# 4           -1.739393           -2.557755            -0.343079
#
#    fg3_pct_last10_home  ast_last10_away  ast_last10_home  reb_last10_away  \
# 0            -1.436764        -0.970572        -0.240887        -1.014203
# 1             1.692500        -0.737027        -0.287715         2.706259
# 2            -1.775063        -0.269938         1.117118         3.811347
# 3            -0.156061        -0.970572         1.117118         0.127721
# 4             0.387633        -0.737027        -0.990131        -1.714092
#
#    reb_last10_home  tov_last10_away  tov_last10_home  spread_last10_away  \
# 0         0.204678        -2.625210        -0.895281           -0.958425
# 1        -1.339627         2.135930         0.328123            1.763350
# 2        -0.397978         0.004076        -0.011712           -1.358686
# 3        -1.527957         2.846548         1.687461            0.642619
# 4         0.355342        -1.061850         3.613189            0.962828
#
#    spread_last10_home  wr_last10_away  wr_last10_home  pts_tot_last20_away  \
# 0           -0.879149        0.913543        0.933922             1.130620
# 1            0.571612       -2.268823       -0.008677            -3.230355
# 2           -0.499973        0.004295        2.347821             0.333087
# 3           -1.571558        0.004295        2.347821            -1.499540
# 4            1.533290       -2.268823       -2.365174            -1.092290
#
#    pts_tot_last20_home  fg_pct_last20_away  fg_pct_last20_home  \
# 0            -0.472773            0.285552           -0.139349
# 1             0.807481           -3.362825            2.335996
# 2            -1.087961           -1.480035            0.285103
# 3             1.007001           -1.593456            1.366893
# 4            -0.123613           -1.139772            2.043012
#
#    ft_pct_last20_away  ft_pct_last20_home  fg3_pct_last20_away  \
# 0            0.766828           -0.788809             1.524571
# 1           -4.653563            1.860226            -3.286237
# 2           -3.243249           -2.085322             1.139506
# 3           -1.249355           -0.517060             1.259526
# 4           -1.905881           -2.906792            -0.405753
#
#    fg3_pct_last20_home  ast_last20_away  ast_last20_home  reb_last20_away  \
# 0            -0.819140        -0.871414        -0.214745        -1.121032
# 1             2.082583        -0.826702        -0.303301         3.061779
# 2            -2.151965        -0.290160         1.290695         4.316622
# 3            -0.174859        -1.094974         1.290695         0.133812
# 4             0.489095        -0.826702        -1.100298        -1.957594
#
#    reb_last20_home  tov_last20_away  tov_last20_home  spread_last20_away  \
# 0        -0.347911        -2.728037        -0.782982           -1.453916
# 1        -1.588151         2.407533         0.336637            1.985592
# 2        -0.493821        -0.057541        -0.058523           -1.544429
# 3        -1.807017         3.229225         1.917276            0.718405
# 4         0.381642        -1.290078         4.156515            1.080459
#
#    spread_last20_home  wr_last20_away  wr_last20_home  \
# 0           -0.765016        1.308409        0.878913
# 1            0.660986       -2.595418       -0.012311
# 2           -0.561301        0.007134        2.661363
# 3           -1.783588        0.007134        2.661363
# 4            1.757909       -2.595418       -2.685986
#
#    pts_tot_last10_loc_away  pts_tot_last10_loc_home  fg_pct_last10_loc_away  \
# 0                 1.344928                -0.277615                1.068917
# 1                -2.646001                 3.255522               -2.775956
# 2                -1.901028                -2.169554               -1.378888
# 3                -1.714784                 0.223862               -2.529415
# 4                -1.342298                -1.052626               -1.419978
#
#    fg_pct_last10_loc_home  ft_pct_last10_loc_away  ft_pct_last10_loc_home  \
# 0               -0.223460                0.733381               -0.392287
# 1                2.816130               -3.855058                1.271507
# 2               -0.536429               -5.060018               -1.287052
# 3                1.820321               -1.188346               -1.246115
# 4                1.256028               -3.499497               -4.101467
#
#    fg3_pct_last10_loc_away  fg3_pct_last10_loc_home  ast_last10_loc_away  \
# 0                 1.327231                -0.106479            -0.583885
# 1                -2.409489                 2.803911            -0.360627
# 2                 0.348440                -2.158409            -1.030402
# 3                -1.209852                -0.692745            -1.030402
# 4                -0.863564                -0.661337            -0.583885
#
#    ast_last10_loc_home  reb_last10_loc_away  reb_last10_loc_home  \
# 0            -0.255118            -1.447180            -0.225178
# 1             0.938000             3.161384            -2.140182
# 2             1.773182             0.957288            -1.182680
# 3             0.938000             2.961012            -1.182680
# 4            -1.358752            -1.046436            -0.225178
#
#    tov_last10_loc_away  tov_last10_loc_home  spread_last10_loc_away  \
# 0            -2.155209            -0.047500               -0.934541
# 1             1.546848            -3.709427                1.251875
# 2            -0.220043            -0.505241               -0.213489
# 3             2.135811             5.262294               -0.864761
# 4            -3.164860             2.058108               -0.050671
#
#    spread_last10_loc_home  wr_last10_loc_away  wr_last10_loc_home  \
# 0               -0.480227            0.839058            1.058779
# 1               -1.491678           -1.787424            1.678589
# 2                0.201403           -1.787424            1.678589
# 3               -0.876012            2.808921            1.678589
# 4                1.894483           -1.787424           -2.660083
#
#    pts_tot_last20_loc_away  pts_tot_last20_loc_home  fg_pct_last20_loc_away  \
# 0                 1.561722                -0.277342                1.263282
# 1                -2.916837                 3.564510               -2.988894
# 2                -2.080840                -2.334591               -1.443828
# 3                -1.871840                 0.267953               -2.716235
# 4                -1.453841                -1.120070               -1.489272
#
#    fg_pct_last20_loc_home  ft_pct_last20_loc_away  ft_pct_last20_loc_home  \
# 0               -0.179305                0.771247               -0.442648
# 1                3.030837               -4.058753                1.419467
# 2               -0.509835               -5.327149               -1.444066
# 3                1.979152               -1.251650               -1.398250
# 4                1.383198               -3.684473               -4.593953
#
#    fg3_pct_last20_loc_away  fg3_pct_last20_loc_home  ast_last20_loc_away  \
# 0                 1.615540                -0.113200            -0.589226
# 1                -2.811726                 3.127728            -0.337869
# 2                 0.455869                -2.398171            -1.091940
# 3                -1.390396                -0.766049            -1.091940
# 4                -0.980115                -0.731075            -0.589226
#
#    ast_last20_loc_home  reb_last20_loc_away  reb_last20_loc_home  \
# 0            -0.238825            -1.764891            -0.227595
# 1             1.093643             3.588091            -2.263768
# 2             2.026370             1.027969            -1.245682
# 3             1.093643             3.355353            -1.245682
# 4            -1.471357            -1.299415            -0.227595
#
#    tov_last20_loc_away  tov_last20_loc_home  spread_last20_loc_away  \
# 0            -2.391767            -0.040463               -1.041687
# 1             1.601322            -4.034616                1.395603
# 2            -0.304470            -0.539732               -0.237900
# 3             2.236586             5.751059               -0.963901
# 4            -3.480791             2.256175               -0.056399
#
#    spread_last20_loc_home  wr_last20_loc_away  wr_last20_loc_home  \
# 0               -0.525997            0.908021            1.157118
# 1               -1.650935           -1.943166            1.836863
# 2                0.232113           -1.943166            1.836863
# 3               -0.966190            3.046411            1.836863
# 4                2.115160           -1.943166           -2.921351
#
#    pts_tot_last50_loc_away  pts_tot_last50_loc_home  fg_pct_last50_loc_away  \
# 0                 1.655750                -0.257426                1.362934
# 1                -3.008159                 3.790287               -3.037730
# 2                -2.137562                -2.424912               -1.438710
# 3                -1.919913                 0.317088               -2.755550
# 4                -1.484615                -1.145312               -1.485740
#
#    fg_pct_last50_loc_home  ft_pct_last50_loc_away  ft_pct_last50_loc_home  \
# 0               -0.117600                0.768568               -0.484899
# 1                3.180876               -4.108924                1.486812
# 2               -0.457225               -5.389790               -1.545257
# 3                2.100252               -1.274219               -1.496744
# 4                1.487898               -3.730963               -4.880533
#
#    fg3_pct_last50_loc_away  fg3_pct_last50_loc_home  ast_last50_loc_away  \
# 0                 1.713395                -0.107785            -0.564238
# 1                -2.922567                 3.285326            -0.295678
# 2                 0.499058                -2.500050            -1.101359
# 3                -1.434237                -0.791289            -1.101359
# 4                -1.004616                -0.754673            -0.564238
#
#    ast_last50_loc_home  reb_last50_loc_away  reb_last50_loc_home  \
# 0            -0.187953            -1.900120            -0.221257
# 1             1.228391             3.664089            -2.285117
# 2             2.219832             1.002946            -1.253187
# 3             1.228391             3.422167            -1.253187
# 4            -1.498072            -1.416276            -0.221257
#
#    tov_last50_loc_away  tov_last50_loc_home  spread_last50_loc_away  \
# 0            -2.506361            -0.039582               -1.069030
# 1             1.578277            -4.097478                1.448640
# 2            -0.371209            -0.546819               -0.238735
# 3             2.228106             5.844367               -0.988679
# 4            -3.620353             2.293708               -0.051249
#
#    spread_last50_loc_home  wr_last50_loc_away  wr_last50_loc_home  \
# 0               -0.554964            0.910546            1.208693
# 1               -1.735008           -1.969599            1.920836
# 2                0.240283           -1.969599            1.920836
# 3               -1.016720            3.070654            1.920836
# 4                2.215574           -1.969599           -3.064161
#
#    spread_odds  covered_spread  team_abbr_home_ATL  team_abbr_home_BKN  \
# 0     0.923105               0               False                True
# 1     0.920217               0               False               False
# 2     0.913242               1               False               False
# 3     0.917431               0               False               False
# 4     0.904977               1               False               False
#
#    team_abbr_home_BOS  team_abbr_home_CHA  team_abbr_home_CHI  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    team_abbr_home_CLE  team_abbr_home_DAL  team_abbr_home_DEN  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    team_abbr_home_DET  team_abbr_home_GSW  team_abbr_home_HOU  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    team_abbr_home_IND  team_abbr_home_LAC  team_abbr_home_LAL  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False                True               False
# 4               False               False                True
#
#    team_abbr_home_MEM  team_abbr_home_MIA  team_abbr_home_MIL  \
# 0               False               False               False
# 1               False                True               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    team_abbr_home_MIN  team_abbr_home_NOP  team_abbr_home_NYK  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    team_abbr_home_OKC  team_abbr_home_ORL  team_abbr_home_PHI  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    team_abbr_home_PHX  team_abbr_home_POR  team_abbr_home_SAC  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    team_abbr_home_SAS  team_abbr_home_TOR  team_abbr_home_UTA  \
# 0               False               False               False
# 1               False               False               False
# 2                True               False               False
# 3               False               False               False
# 4               False               False               False
#
#    team_abbr_home_WAS
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False

# %%
# Data split
X_train = game_df[game_df['season'].isin(['2012-13', '2013-14', '2014-15', '2015-16', '2016-17'])]
X_val = game_df[game_df['season'] == '2017-18']
X_test = game_df[game_df['season'] == '2018-19']

# Separate labels
y_train = X_train[['spread', 'vegas_spread', 'covered_spread']]
y_val = X_val[['spread', 'vegas_spread', 'covered_spread']]
y_test = X_test[['spread', 'vegas_spread', 'covered_spread']]

# Separate odds
odds_train = X_train[['spread_odds']]
odds_val = X_val[['spread_odds']]
odds_test = X_test[['spread_odds']]

# Remove labels from features
X_train = X_train.drop(['spread', 'vegas_spread', 'covered_spread', 'spread_odds'], axis=1)
X_val = X_val.drop(['spread', 'vegas_spread', 'covered_spread', 'spread_odds'], axis=1)
X_test = X_test.drop(['spread', 'vegas_spread', 'covered_spread', 'spread_odds'], axis=1)

# Reset index
odds_train = odds_train.reset_index(drop=True)
odds_val = odds_val.reset_index(drop=True)
odds_test = odds_test.reset_index(drop=True)
X_train = X_train.reset_index(drop=True)
X_val = X_val.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# Save data
odds_train.to_csv(os.path.join(DATA_PATH_PROC, 'odds_train.csv'), index=False)
odds_val.to_csv(os.path.join(DATA_PATH_PROC, 'odds_val.csv'), index=False)
odds_test.to_csv(os.path.join(DATA_PATH_PROC, 'odds_test.csv'), index=False)
X_train.to_csv(os.path.join(DATA_PATH_PROC, 'X_train.csv'), index=False)
X_val.to_csv(os.path.join(DATA_PATH_PROC, 'X_val.csv'), index=False)
X_test.to_csv(os.path.join(DATA_PATH_PROC, 'X_test.csv'), index=False)
y_train.to_csv(os.path.join(DATA_PATH_PROC, 'y_train.csv'), index=False)
y_val.to_csv(os.path.join(DATA_PATH_PROC, 'y_val.csv'), index=False)
y_test.to_csv(os.path.join(DATA_PATH_PROC, 'y_test.csv'), index=False)
